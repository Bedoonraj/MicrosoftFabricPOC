# %% [markdown]
# ### Metadata Table

# %%
spark.sql("""
CREATE TABLE config_profiling_classifn_metadata (
    id INT,
    database_name STRING,
    table_name STRING,
    profileandclassification_ind INT,
    nlpcheck_ind INT,
    output_table STRING,
    abfss_location STRING)
""")
# Out:
# StatementMeta(, 77505bb2-bfe5-4411-9210-c6d2fe703ca3, 3, Finished, Available)
# DataFrame[]

# %%
spark.sql("""
INSERT INTO config_profiling_classifn_metadata 
VALUES 
    (1, 'clinician_services', 'Clinician_Demographic_Information', 1, 0, 'table_profiles_classifiers', 'abfss://ed48e609-f66b-4cc4-832c-588ba37d0047@onelake.dfs.fabric.microsoft.com/e50527ec-11eb-4319-9a37-6a3ea5c7f29a/Files/source_file_temp/Clinician_Demographic_Information'),
    (2, 'clinician_services', 'Clinician_Utilization', 1, 0, 'table_profiles_classifiers', 'abfss://ed48e609-f66b-4cc4-832c-588ba37d0047@onelake.dfs.fabric.microsoft.com/e50527ec-11eb-4319-9a37-6a3ea5c7f29a/Files/source_file_temp/Clinician_Utilization'),
    (3, 'clinician_services', 'ec_public_reporting', 1, 0, 'table_profiles_classifiers', 'abfss://ed48e609-f66b-4cc4-832c-588ba37d0047@onelake.dfs.fabric.microsoft.com/e50527ec-11eb-4319-9a37-6a3ea5c7f29a/Files/source_file_temp/ec_public_reporting'),
    (4, 'clinician_services', 'ec_score_file', 1, 0, 'table_profiles_classifiers', 'abfss://ed48e609-f66b-4cc4-832c-588ba37d0047@onelake.dfs.fabric.microsoft.com/e50527ec-11eb-4319-9a37-6a3ea5c7f29a/Files/source_file_temp/ec_score_file'),
    (5, 'clinician_services', 'Facility_Affiliation', 1, 0, 'table_profiles_classifiers', 'abfss://ed48e609-f66b-4cc4-832c-588ba37d0047@onelake.dfs.fabric.microsoft.com/e50527ec-11eb-4319-9a37-6a3ea5c7f29a/Files/source_file_temp/Facility_Affiliation'),
    (6, 'clinician_services', 'grp_public_reporting', 1, 0, 'table_profiles_classifiers', 'abfss://ed48e609-f66b-4cc4-832c-588ba37d0047@onelake.dfs.fabric.microsoft.com/e50527ec-11eb-4319-9a37-6a3ea5c7f29a/Files/source_file_temp/grp_public_reporting'),
    (7, 'clinician_services', 'grp_public_reporting_cahps', 1, 0, 'table_profiles_classifiers', 'abfss://ed48e609-f66b-4cc4-832c-588ba37d0047@onelake.dfs.fabric.microsoft.com/e50527ec-11eb-4319-9a37-6a3ea5c7f29a/Files/source_file_temp/grp_public_reporting_cahps')
""")
# Out:
# StatementMeta(, 77505bb2-bfe5-4411-9210-c6d2fe703ca3, 4, Finished, Available)
# DataFrame[]
